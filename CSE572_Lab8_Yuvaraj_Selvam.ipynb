# %% [markdown]
# # CSE 572: Lab 8
#
# In this lab, you will practice implementing feed-forward and convolutional neural networks.
#
# To execute and make changes to this notebook, click File > Save a copy to save your own version in your Google Drive or Github. Read the step-by-step instructions below carefully. To execute the code, click on each cell below and press the SHIFT-ENTER keys simultaneously or by clicking the Play button.
#
# When you finish executing all code/exercises, save your notebook then download a copy (.ipynb file). Submit the following **three** things:
# 1. a link to your Colab notebook,
# 2. the .ipynb file, and
# 3. a pdf of the executed notebook on Canvas.
#
# To generate a pdf of the notebook, click File > Print > Save as PDF.

# %%
# Import libraries
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# Set the random seed for reproducibility
seed = 0
tf.random.set_seed(seed)

# %% [markdown]
# ## Feed-forward neural networks
#
# Describe

# %% [markdown]
# ### Load the dataset
#
# For this example, we will use the [Cleveland Heart Disease dataset](https://archive.ics.uci.edu/ml/datasets/heart+Disease). Review the dataset documentation to learn more about the attributes and other aspects of the dataset. The dataset consists of a CSV file with 303 rows. Each row contains information about a patient. There are 14 attribute columns and one binary class column (`target`) that reports whether or not a patient had a heart disease. We will train a feed-forward neural network model to predict whether or not a given patient has a heart disease based on the attribute values.

# %%
# Load the dataset
data = pd.read_csv("http://storage.googleapis.com/download.tensorflow.org/data/heart.csv")

# %%
# Print sample rows
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
# Print the number of rows and columns
data.shape
# Out:
# (303, 14)

# %% [markdown]
# Split the dataset into three randomly-sampled subsets: training (60%), validation (20%), and test (20%).

# %%
# YOUR CODE HERE
train = data.sample(frac=0.6, random_state=seed)
data_remaining = data.drop(train.index)
val = data_remaining.sample(frac=0.5, random_state=seed)
test = data_remaining.drop(val.index)

# %% [markdown]
# Print the number of samples in each of the three subsets and the number of instances from each class. For example, for the training set you might print "The training set has __ instances (__ heart disease, __ no disease)".

# %%
# YOUR CODE HERE
trainDiseaseCount = train[train['target'] == 1].shape[0]
valDiseaseCount = val[val['target'] == 1].shape[0]
testDiseaseCount = test[test['target'] == 1].shape[0]
print(f"The training set has {train.shape[0]} instances ({trainDiseaseCount} heart disease, {train.shape[0] - trainDiseaseCount} no disease)")
print(f"The validation set has {val.shape[0]} instances ({valDiseaseCount} heart disease, {val.shape[0] - valDiseaseCount} no disease)")
print(f"The test set has {test.shape[0]} instances ({testDiseaseCount} heart disease, {test.shape[0] - testDiseaseCount} no disease)")
# Out:
# The training set has 182 instances (49 heart disease, 133 no disease)
# The validation set has 60 instances (16 heart disease, 44 no disease)
# The test set has 61 instances (18 heart disease, 43 no disease)

# %% [markdown]
# ### Prepare the dataset
#
# Before we can feed this dataset to our model for training and evaluation, we need to perform a few steps to get it ready:
# 1. Convert the dataframes to Dataset objects
# 2. Normalize the numerical feature values
# 3. Binarize the Categorical features by converting to one-hot encodings

# %%
# Convert dataframes to Dataset objects
def dataframe_to_dataset(df):
    df = df.copy()
    # Remove the target column and store in a separate array
    labels = df.pop('target')
    ds = tf.data.Dataset.from_tensor_slices((dict(df), labels))
    ds = ds.shuffle(buffer_size=len(df), reshuffle_each_iteration=False)
    return ds


train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %% [markdown]
# The Dataset object yields a tuple containing the input feature vector and target (class value): `(input, target)`. `input` is a dictionary of features and `target` is the value 0 or 1. The code below prints an example instance drawn from the training Dataset object.

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("\nTarget:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=61>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=4>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=148>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=203>, 'fbs': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'restecg': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'thalach': <tf.Tensor: shape=(), dtype=int64, numpy=161>, 'exang': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'oldpeak': <tf.Tensor: shape=(), dtype=float64, numpy=0.0>, 'slope': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'ca': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'thal': <tf.Tensor: shape=(), dtype=string, numpy=b'reversible'>}
#
# Target: tf.Tensor(1, shape=(), dtype=int64)

# %% [markdown]
# We can use the batch() function in keras to create batches from the full dataset for passing to the model. For the training dataset, we'll define a hyperparameter `batch_size` that we will set. For the validation and test sets, we will make the batch size equivalent to the size of the subset so all samples in that subset are evaluated each time the dataset is evaluated by the model.

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(val.shape[0])
test_ds = test_ds.batch(test.shape[0])

# %% [markdown]
# There are seven categorical features in the dataset: `sex`, `cp`, `fbs`, `restecg`, `exang`, `ca`, and `thal`. You can read more about what these features mean in the [dataset documentation](https://archive.ics.uci.edu/ml/datasets/heart+Disease). All of them except `thal` have integer data type while `thal` has String data type. Below we define a function to encode these feature values as one-hot encodings using the [IntegerLookup()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/IntegerLookup) and [StringLookup()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/StringLookup) layers. These layers create look-up tables for mapping a set of arbitrary integers or strings to a one-hot encoding. We use an `is_string` argument to indicate whether we should use the `StringLookup()` for `thal` or the `IntegerLookup()` for the remaining features.

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    from tensorflow.keras.layers import IntegerLookup
    from tensorflow.keras.layers import StringLookup
    
    # Create lookup layer to turn categorical features into 1-hot integer encodings
    if is_string:
        lookup = StringLookup(output_mode="binary")
    else:
        lookup = IntegerLookup(output_mode="binary")

    # Prepare a Dataset that only yields the feature of interest
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Find the set of possible values and assign them a fixed integer index
    lookup.adapt(feature_ds)

    # Turn the input into integer indices
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# The remaining features in the dataset (`age`, `trestbps`, `chol`, `thalach`, `oldpeak`, and `slope`) are all numerical measurements. You can read more about what these features mean in the [dataset documentation](https://archive.ics.uci.edu/ml/datasets/heart+Disease). We don't need to encode the numerical features, but we do want to scale them to the same range of values (e.g., using standardization or normalization). Below we define a function that uses the [Normalization()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Normalization) layer to standardize the data (subtract the mean and divide by the standard deviation for each feature).

# %%
def normalize(feature, name, dataset):
    from tensorflow.keras.layers import Normalization
    
    # Create a Normalization layer for our feature
    normalizer = Normalization()

    # Prepare a Dataset that only yields the feature of interest
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    norm_feature = normalizer(feature)
    return norm_feature

# %% [markdown]
# Now we can apply these functions to each of our features and return an encoded/preprocessed input layer. We first create tensor variables for each of the inputs, then apply the appropriate function, then concatenate all of these input layers for each feature together to form a single input feature layer.

# %%
all_inputs = [
    keras.Input(shape=(1,), name="sex", dtype="int64"),
    keras.Input(shape=(1,), name="cp", dtype="int64"),
    keras.Input(shape=(1,), name="fbs", dtype="int64"),
    keras.Input(shape=(1,), name="restecg", dtype="int64"),
    keras.Input(shape=(1,), name="exang", dtype="int64"),
    keras.Input(shape=(1,), name="ca", dtype="int64"),
    keras.Input(shape=(1,), name="thal", dtype="string"),
    keras.Input(shape=(1,), name="age"),
    keras.Input(shape=(1,), name="trestbps"),
    keras.Input(shape=(1,), name="chol"),
    keras.Input(shape=(1,), name="thalach"),
    keras.Input(shape=(1,), name="oldpeak"),
    keras.Input(shape=(1,), name="slope"),
]

# %%
feature_layer = layers.concatenate(
    [
        encode_categorical_feature(all_inputs[0], "sex", train_ds, False),
        encode_categorical_feature(all_inputs[1], "cp", train_ds, False),
        encode_categorical_feature(all_inputs[2], "fbs", train_ds, False),
        encode_categorical_feature(all_inputs[3], "restecg", train_ds, False),
        encode_categorical_feature(all_inputs[4], "exang", train_ds, False),
        encode_categorical_feature(all_inputs[5], "ca", train_ds, False),
        encode_categorical_feature(all_inputs[6], "thal", train_ds, True),
        normalize(all_inputs[7], "age", train_ds),
        normalize(all_inputs[8], "trestbps", train_ds),
        normalize(all_inputs[9], "chol", train_ds),
        normalize(all_inputs[10], "thalach", train_ds),
        normalize(all_inputs[11], "oldpeak", train_ds),
        normalize(all_inputs[12], "slope", train_ds)
    ]
)

# %% [markdown]
# ### Build the model
#
# Now that we've prepared our dataset, we can construct our neural network model. We construct the model by composing Layer objects starting with the input layer (which we've already defined as `feature_layer`) and ending with the output layer (which will be the final output of the model). In this example, we will only use [Dense()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layers which are simple fully-connected feed-forward layers (i.e., each output from layer `i-1` is connected by a weight variable to every neuron in layer `i`). We will create a network with only one hidden layer (between the input and output layers).
#
# The Dense() layer object allows us to specify the activation function to use using the `activation` argument. In class, we talked about several activation functions including sigmoid, sign, and tanh. Another commonly used activation function is the rectified linear unit, or "ReLU" function. Another commonly used activation function is the rectified linear unit, or "ReLU" function, which has the equation $a(z)=max(0,z)$. We will use `relu` as our activation function in this example for all layers except the final layer, which will use a `sigmoid` activation.

# %%
# Create a variable for the number of units/neurons in the layer
h1_units = 32
# Create a Dense layer and append it to the input layer
h1_layer = layers.Dense(h1_units, activation='relu')(feature_layer)

# Create an output layer with one output representing the likelihood of 
# heart disease and append it to the hidden layer
output_layer = layers.Dense(1, activation="sigmoid")(h1_layer)

# Build the model specifying the input and output layer
model = keras.Model(inputs=all_inputs, outputs=output_layer)

# %% [markdown]
# We can plot our completed model to visualize the input, hidden, and output layers.

# %%
# `rankdir='LR'` is to make the graph horizontal
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Next we compile the model by specifying the optimization technique and loss function to be used in model training. We can also specify the metric(s) that will be logged during training. We will use stochastic gradient descent (`sgd`) for the optimizer and binary cross entropy (log loss) as the loss function. We will log the accuracy metric during training. We can also specify the learning rate hyperparameter here.

# %%
lr = 0.01
model.compile(keras.optimizers.SGD(learning_rate=lr), "binary_crossentropy", metrics=["accuracy"])

# %% [markdown]
# ### Train the model
#
# Now that we've constructed and compiled our model, we can train the model using our training dataset. This is done in keras using the `fit()` function, which also gives us an option to provide the validation dataset which will be used to evaluate validation accuracy after every epoch.

# %%
model_result = model.fit(train_ds, epochs=100, validation_data=val_ds)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 70ms/step - loss: 0.5745 - accuracy: 0.7582 - val_loss: 0.5673 - val_accuracy: 0.7667
# Epoch 2/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5589 - accuracy: 0.7747 - val_loss: 0.5539 - val_accuracy: 0.7667
# Epoch 3/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5448 - accuracy: 0.7802 - val_loss: 0.5418 - val_accuracy: 0.7667
# Epoch 4/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5321 - accuracy: 0.7857 - val_loss: 0.5306 - val_accuracy: 0.7667
# Epoch 5/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5206 - accuracy: 0.7857 - val_loss: 0.5203 - val_accuracy: 0.7667
# Epoch 6/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5100 - accuracy: 0.7857 - val_loss: 0.5108 - val_accuracy: 0.7833
# Epoch 7/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5003 - accuracy: 0.7857 - val_loss: 0.5020 - val_accuracy: 0.7833
# Epoch 8/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4914 - accuracy: 0.7857 - val_loss: 0.4938 - val_accuracy: 0.8000
# Epoch 9/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4830 - accuracy: 0.7912 - val_loss: 0.4861 - val_accuracy: 0.8000
# Epoch 10/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4753 - accuracy: 0.7912 - val_loss: 0.4790 - val_accuracy: 0.8000
# Epoch 11/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4682 - accuracy: 0.7967 - val_loss: 0.4723 - val_accuracy: 0.8000
# Epoch 12/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4615 - accuracy: 0.8022 - val_loss: 0.4661 - val_accuracy: 0.8167
# Epoch 13/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4553 - accuracy: 0.8022 - val_loss: 0.4602 - val_accuracy: 0.8167
# Epoch 14/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4494 - accuracy: 0.8022 - val_loss: 0.4547 - val_accuracy: 0.8167
# Epoch 15/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4438 - accuracy: 0.8077 - val_loss: 0.4495 - val_accuracy: 0.8000
# Epoch 16/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4386 - accuracy: 0.8077 - val_loss: 0.4445 - val_accuracy: 0.8000
# Epoch 17/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4336 - accuracy: 0.8077 - val_loss: 0.4399 - val_accuracy: 0.8000
# Epoch 18/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4289 - accuracy: 0.8077 - val_loss: 0.4355 - val_accuracy: 0.8000
# Epoch 19/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4245 - accuracy: 0.8077 - val_loss: 0.4313 - val_accuracy: 0.7833
# Epoch 20/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4203 - accuracy: 0.8077 - val_loss: 0.4274 - val_accuracy: 0.7833
# Epoch 21/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4163 - accuracy: 0.8022 - val_loss: 0.4236 - val_accuracy: 0.8000
# Epoch 22/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4124 - accuracy: 0.8022 - val_loss: 0.4200 - val_accuracy: 0.7833
# Epoch 23/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4087 - accuracy: 0.8022 - val_loss: 0.4166 - val_accuracy: 0.8000
# Epoch 24/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4051 - accuracy: 0.8022 - val_loss: 0.4134 - val_accuracy: 0.7833
# Epoch 25/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4017 - accuracy: 0.7967 - val_loss: 0.4103 - val_accuracy: 0.8000
# Epoch 26/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3984 - accuracy: 0.7967 - val_loss: 0.4073 - val_accuracy: 0.8000
# Epoch 27/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3953 - accuracy: 0.7967 - val_loss: 0.4045 - val_accuracy: 0.8167
# Epoch 28/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3922 - accuracy: 0.7967 - val_loss: 0.4018 - val_accuracy: 0.8167
# Epoch 29/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3893 - accuracy: 0.8022 - val_loss: 0.3992 - val_accuracy: 0.8167
# Epoch 30/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3865 - accuracy: 0.8132 - val_loss: 0.3967 - val_accuracy: 0.8167
# Epoch 31/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3838 - accuracy: 0.8187 - val_loss: 0.3943 - val_accuracy: 0.8167
# Epoch 32/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3811 - accuracy: 0.8242 - val_loss: 0.3920 - val_accuracy: 0.8167
# Epoch 33/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3786 - accuracy: 0.8297 - val_loss: 0.3898 - val_accuracy: 0.8167
# Epoch 34/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3761 - accuracy: 0.8242 - val_loss: 0.3876 - val_accuracy: 0.8167
# Epoch 35/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3737 - accuracy: 0.8242 - val_loss: 0.3856 - val_accuracy: 0.8167
# Epoch 36/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3714 - accuracy: 0.8242 - val_loss: 0.3837 - val_accuracy: 0.8333
# Epoch 37/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3691 - accuracy: 0.8242 - val_loss: 0.3818 - val_accuracy: 0.8333
# Epoch 38/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3669 - accuracy: 0.8242 - val_loss: 0.3800 - val_accuracy: 0.8333
# Epoch 39/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3648 - accuracy: 0.8242 - val_loss: 0.3783 - val_accuracy: 0.8333
# Epoch 40/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3628 - accuracy: 0.8297 - val_loss: 0.3767 - val_accuracy: 0.8333
# Epoch 41/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3608 - accuracy: 0.8352 - val_loss: 0.3751 - val_accuracy: 0.8333
# Epoch 42/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3588 - accuracy: 0.8352 - val_loss: 0.3736 - val_accuracy: 0.8333
# Epoch 43/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3569 - accuracy: 0.8352 - val_loss: 0.3722 - val_accuracy: 0.8333
# Epoch 44/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3550 - accuracy: 0.8352 - val_loss: 0.3708 - val_accuracy: 0.8333
# Epoch 45/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3533 - accuracy: 0.8352 - val_loss: 0.3695 - val_accuracy: 0.8333
# Epoch 46/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3515 - accuracy: 0.8352 - val_loss: 0.3683 - val_accuracy: 0.8333
# Epoch 47/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3498 - accuracy: 0.8407 - val_loss: 0.3670 - val_accuracy: 0.8333
# Epoch 48/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3482 - accuracy: 0.8407 - val_loss: 0.3659 - val_accuracy: 0.8333
# Epoch 49/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3466 - accuracy: 0.8462 - val_loss: 0.3648 - val_accuracy: 0.8333
# Epoch 50/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3450 - accuracy: 0.8462 - val_loss: 0.3637 - val_accuracy: 0.8333
# Epoch 51/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3435 - accuracy: 0.8462 - val_loss: 0.3626 - val_accuracy: 0.8500
# Epoch 52/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3420 - accuracy: 0.8462 - val_loss: 0.3616 - val_accuracy: 0.8500
# Epoch 53/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3406 - accuracy: 0.8462 - val_loss: 0.3606 - val_accuracy: 0.8500
# Epoch 54/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3392 - accuracy: 0.8462 - val_loss: 0.3597 - val_accuracy: 0.8500
# Epoch 55/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3378 - accuracy: 0.8462 - val_loss: 0.3588 - val_accuracy: 0.8500
# Epoch 56/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3364 - accuracy: 0.8462 - val_loss: 0.3579 - val_accuracy: 0.8500
# Epoch 57/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3351 - accuracy: 0.8462 - val_loss: 0.3570 - val_accuracy: 0.8500
# Epoch 58/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3339 - accuracy: 0.8462 - val_loss: 0.3562 - val_accuracy: 0.8500
# Epoch 59/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3326 - accuracy: 0.8462 - val_loss: 0.3553 - val_accuracy: 0.8500
# Epoch 60/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3314 - accuracy: 0.8462 - val_loss: 0.3545 - val_accuracy: 0.8500
# Epoch 61/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3301 - accuracy: 0.8462 - val_loss: 0.3537 - val_accuracy: 0.8500
# Epoch 62/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3290 - accuracy: 0.8462 - val_loss: 0.3530 - val_accuracy: 0.8500
# Epoch 63/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3278 - accuracy: 0.8462 - val_loss: 0.3522 - val_accuracy: 0.8500
# Epoch 64/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3267 - accuracy: 0.8462 - val_loss: 0.3515 - val_accuracy: 0.8500
# Epoch 65/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3256 - accuracy: 0.8462 - val_loss: 0.3508 - val_accuracy: 0.8500
# Epoch 66/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3245 - accuracy: 0.8462 - val_loss: 0.3501 - val_accuracy: 0.8500
# Epoch 67/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3234 - accuracy: 0.8462 - val_loss: 0.3495 - val_accuracy: 0.8500
# Epoch 68/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3224 - accuracy: 0.8462 - val_loss: 0.3488 - val_accuracy: 0.8500
# Epoch 69/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3213 - accuracy: 0.8462 - val_loss: 0.3482 - val_accuracy: 0.8500
# Epoch 70/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3203 - accuracy: 0.8462 - val_loss: 0.3476 - val_accuracy: 0.8500
# Epoch 71/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3193 - accuracy: 0.8462 - val_loss: 0.3470 - val_accuracy: 0.8500
# Epoch 72/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3184 - accuracy: 0.8462 - val_loss: 0.3464 - val_accuracy: 0.8500
# Epoch 73/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3174 - accuracy: 0.8462 - val_loss: 0.3458 - val_accuracy: 0.8500
# Epoch 74/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3165 - accuracy: 0.8462 - val_loss: 0.3453 - val_accuracy: 0.8500
# Epoch 75/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3156 - accuracy: 0.8462 - val_loss: 0.3447 - val_accuracy: 0.8500
# Epoch 76/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3147 - accuracy: 0.8516 - val_loss: 0.3442 - val_accuracy: 0.8500
# Epoch 77/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3138 - accuracy: 0.8516 - val_loss: 0.3437 - val_accuracy: 0.8500
# Epoch 78/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3129 - accuracy: 0.8516 - val_loss: 0.3432 - val_accuracy: 0.8500
# Epoch 79/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3121 - accuracy: 0.8516 - val_loss: 0.3427 - val_accuracy: 0.8500
# Epoch 80/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3112 - accuracy: 0.8516 - val_loss: 0.3422 - val_accuracy: 0.8500
# Epoch 81/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3104 - accuracy: 0.8516 - val_loss: 0.3417 - val_accuracy: 0.8500
# Epoch 82/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3096 - accuracy: 0.8516 - val_loss: 0.3413 - val_accuracy: 0.8500
# Epoch 83/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3088 - accuracy: 0.8516 - val_loss: 0.3408 - val_accuracy: 0.8500
# Epoch 84/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3080 - accuracy: 0.8516 - val_loss: 0.3404 - val_accuracy: 0.8500
# Epoch 85/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3072 - accuracy: 0.8516 - val_loss: 0.3400 - val_accuracy: 0.8500
# Epoch 86/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3064 - accuracy: 0.8516 - val_loss: 0.3396 - val_accuracy: 0.8500
# Epoch 87/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3056 - accuracy: 0.8516 - val_loss: 0.3391 - val_accuracy: 0.8500
# Epoch 88/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3049 - accuracy: 0.8516 - val_loss: 0.3387 - val_accuracy: 0.8500
# Epoch 89/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3041 - accuracy: 0.8516 - val_loss: 0.3384 - val_accuracy: 0.8500
# Epoch 90/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3034 - accuracy: 0.8516 - val_loss: 0.3380 - val_accuracy: 0.8500
# Epoch 91/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3027 - accuracy: 0.8571 - val_loss: 0.3376 - val_accuracy: 0.8500
# Epoch 92/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3019 - accuracy: 0.8571 - val_loss: 0.3372 - val_accuracy: 0.8500
# Epoch 93/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3012 - accuracy: 0.8571 - val_loss: 0.3369 - val_accuracy: 0.8500
# Epoch 94/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3005 - accuracy: 0.8571 - val_loss: 0.3365 - val_accuracy: 0.8500
# Epoch 95/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2998 - accuracy: 0.8571 - val_loss: 0.3362 - val_accuracy: 0.8500
# Epoch 96/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2992 - accuracy: 0.8571 - val_loss: 0.3359 - val_accuracy: 0.8500
# Epoch 97/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2985 - accuracy: 0.8571 - val_loss: 0.3355 - val_accuracy: 0.8500
# Epoch 98/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2978 - accuracy: 0.8571 - val_loss: 0.3352 - val_accuracy: 0.8500
# Epoch 99/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2971 - accuracy: 0.8626 - val_loss: 0.3349 - val_accuracy: 0.8500
# Epoch 100/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2965 - accuracy: 0.8626 - val_loss: 0.3346 - val_accuracy: 0.8500

# %% [markdown]
# The `fit()` function returns a history attribute that gives the metrics recorded during training as a dictionary. We can print the dictionary keys to see which metrics were stored:

# %%
model_result.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Create a figure with two subplots. The first subplot should plot the training and validation loss (`loss` and `val_loss`) and the second subplot should plot the training and validation accuracy (`accuracy` and `val_accuracy`). Make sure you include the axis labels and a legend in each plot.

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))

# YOUR CODE HERE
ax1.plot(range(1,101), model_result.history['loss'], '-r', range(1,101), model_result.history['val_loss'], 'b--')
ax2.plot(range(1,101), model_result.history['accuracy'], '-r', range(1,101), model_result.history['val_accuracy'], 'b--')

ax1.legend(['Training Loss','Validation Loss'])
ax1.set_xlabel('No. of Epochs')
ax1.set_ylabel('Loss')

ax2.legend(['Training Accuracy','Validation Accuracy'])
ax2.set_xlabel('No. of Epochs')
ax2.set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# **Question 3: If we train our model for too long (too many epochs), we run the risk of overfitting to the training data which will have a negative effect on our model's generalization to the validation dataset. Try changing the number of epochs to 1000 and re-training. Around how many epochs do you see the model begin to overfit?**
#
# **Answer:**
#
# The model starts to overfit at around 200 epochs because that's where the validation accuracy stops increasing while the training accuracy is still increasing. This is evident in loss plot as well.

# %% [markdown]
# ### Test the model
#
# Finally, we evaluate our trained model on the held-out test set. First we predict the outputs for the test data.

# %%
preds = model.predict(test_ds)

# %% [markdown]
# The model output from the final sigmoid layer is a value between 0 and 1 representing the likelihood that a given sample patient has heart disease. To get the predicted classes, we predict 1 if the output was >= 0.5 and 0 otherwise.

# %%
pred_classes = [1 if p >= 0.5 else 0 for p in preds]

# %%
from sklearn.metrics import accuracy_score


# YOUR CODE HERE
y_true = [y for x,y in test_ds][0]
accuracy_score(y_true, pred_classes)
# Out:
# 0.8032786885245902

# %% [markdown]
# Compute and print the test accuracy.

# %% [markdown]
# **Question 2: There is a large difference between the training and validation accuracies and the test accuracy. What do you think could explain this difference?**
#
# **Answer:**
#
# The difference could've been because the data that we used to train the model may not have been correctly representative of real-world data for each class. This would mean that the model hasn't learned the patterns that occur in test (real-world) data.

# %% [markdown]
# ## Convolutional neural networks
#
# The previous example used a structured dataset of pre-determined features to predict the likelihood of heart disease in a patient. This type of dataset is well suited for a feed-forward neural network (FFNN) architecture. However, other datasets may not be as well suited for this type of architecture. For example, to train a FFNN to classify an image dataset, we would need to convert each image (which has dimension $N \times M \times K$ where $N$ and $M$ are the image dimensions and $K$ is the number of color channels - 3 for RGB) to a feature vector representation. We can do this by flattening the image to a 1D feature vector so the new dimension would be $N * M * K \times 1$, but this would remove the 2D spatial structure.
#
# Convolutional neural networks (CNNs) are another type of neural network architecture that enables spatial relationships to be learned from the data. The features learned in each hidden layer have 2D structures that act as filters on the spatial inputs, rather than scalar activations like in a FFNN. In this example, we'll train a CNN to classify an image dataset.

# %% [markdown]
# ### Load the dataset
#
# For this example we'll use the [FashionMNIST dataset](https://keras.io/api/datasets/fashion_mnist/). This is a dataset of 60,000 28x28 color training images and 10,000 test images with 10 class labels:
#
# 0.	t-shirt
# 1.	trouser
# 2.	pullover
# 3.	dress
# 4.	coat
# 5.	sandal
# 6.	shirt
# 7.	sneaker
# 8.	bag
# 9.	boot

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
# Print the dimensions of the datasets

print('Training data input dim: ', x_train.shape)
print('Training data label dim: ', y_train.shape)
print('Test data input dim: ', x_test.shape)
print('Test data label dim: ', y_test.shape)
# Out:
# Training data input dim:  (60000, 28, 28)
# Training data label dim:  (60000,)
# Test data input dim:  (10000, 28, 28)
# Test data label dim:  (10000,)

# %%
# Set variable for number of classes
num_classes = 10

# %% [markdown]
# Next we'll plot a few random images from the training set to get an idea of what the data look like. You can run this as many times as you want to see a different random subset of images.

# %%
# number of images to plot
n = 5

# create a dictionary for the label names
labels = {
    0: 't-shirt',
    1: 'trouser',
    2: 'pullover',
    3: 'dress',
    4: 'coat',
    5: 'sandal',
    6: 'shirt',
    7: 'sneaker',
    8: 'bag',
    9: 'boot'
}


# Randomly sample n sample indices
rand_inds = np.random.randint(0, x_train.shape[0], n)

fig, axes = plt.subplots(ncols=n)
for i, ax in enumerate(axes):
    ax.imshow(x_train[rand_inds[i]], cmap='gray')
    ax.set_title(labels[y_train[rand_inds[i]]])
    ax.axis('off')

# %% [markdown]
# The class is currently a categorical variable with values 0 to 9. We need to convert this to a one-hot integer encoding.

# %%
# convert class category to one hot vector
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ### Build the model
#
# We will construct a model in the same way as the previous example by composing layers starting with the input layer and ending with the output layer. However in this example, we will use [Conv2D()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) layers instead of Dense() layers as our hidden layers. In addition to specifying the number of neurons/filters and activation function for each Conv2D() layer, we need to specify the kernel size (the size of the convolutional kernel/filter). We will use $3\times3$ convolutions for all layers in this example. Each Conv2D() layer is followed by a [MaxPool2D()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) layer to enable invariance to small translations.
#
# We will still use a Dense() layer for the final output layer. Previously we used the sigmoid activation in our final layer, but this is only used for binary classification outputs (0 to 1). Since this is a multi-class classification, we will use the [softmax function](https://www.tensorflow.org/api_docs/python/tf/keras/activations/softmax) which returns the log odds for the multi-class case.

# %%
# Define the input layer
input_layer = keras.Input(shape=[x_train.shape[1], x_train.shape[2], 1])

# Define one hidden layer of Conv2D + Max Pooling
h1 = layers.Conv2D(32, kernel_size=(3, 3), activation="relu")(input_layer)
h1 = layers.MaxPooling2D(pool_size=(2, 2))(h1)

# Define a second Conv2D layer with 64 units, 3x3 kernel, and relu activation
h2 = layers.Conv2D(64, kernel_size=(3, 3), activation="relu")(h1) # YOUR CODE HERE

# Define a second MaxPooling2D layer with 2x2 pool size
h2 = layers.MaxPooling2D(pool_size=(2, 2))(h2) # YOUR CODE HERE

# Flatten the output from the last hidden layer so it can be passed to Dense layer
h2 = layers.Flatten()(h2)

# Final output layer
output = layers.Dense(num_classes, activation="softmax")(h2)

# Build the model specifying the input and output layer
model = keras.Model(inputs=input_layer, outputs=output)

# %% [markdown]
# We can plot our completed model to visualize the input, hidden, and output layers.

# %%
# `rankdir='LR'` is to make the graph horizontal
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Another way to visualize our model is to print a table of the layers and the shape of the representation at each layer using the `model.summary()` function.

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_9 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model
#
# Now that we've constructed our model, we can compile and train the model as in the previous example. Since we are doing a multi-class classification, we use the [categorical cross-entropy](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/categorical_crossentropy) loss function instead of binary-cross entropy.
#
# In the first example, we created our own train/val/test subsets. In this example, the FashionMNIST dataset provided a train/test split but not a validation subset. We can have keras automatically split out a fraction of the training data using the `validation_split` argument to `model.fit()` as shown below.

# %%
batch_size = 512
epochs = 10

model.compile(loss="categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])

model_result = model.fit(x_train, y_train, 
                         batch_size=batch_size,
                         epochs=epochs, 
                         validation_split=0.2)
# Out:
# Epoch 1/10
# 94/94 [==============================] - 35s 367ms/step - loss: 13.9555 - accuracy: 0.2237 - val_loss: 1.9591 - val_accuracy: 0.3773
# Epoch 2/10
# 94/94 [==============================] - 35s 369ms/step - loss: 1.5469 - accuracy: 0.5068 - val_loss: 1.1200 - val_accuracy: 0.5926
# Epoch 3/10
# 94/94 [==============================] - 34s 367ms/step - loss: 0.9673 - accuracy: 0.6524 - val_loss: 0.8872 - val_accuracy: 0.6873
# Epoch 4/10
# 94/94 [==============================] - 33s 352ms/step - loss: 0.8173 - accuracy: 0.7097 - val_loss: 0.8796 - val_accuracy: 0.6812
# Epoch 5/10
# 94/94 [==============================] - 34s 365ms/step - loss: 0.7361 - accuracy: 0.7386 - val_loss: 0.7467 - val_accuracy: 0.7310
# Epoch 6/10
# 94/94 [==============================] - 33s 353ms/step - loss: 0.6870 - accuracy: 0.7554 - val_loss: 0.6725 - val_accuracy: 0.7639
# Epoch 7/10
# 94/94 [==============================] - 33s 352ms/step - loss: 0.6514 - accuracy: 0.7682 - val_loss: 0.6887 - val_accuracy: 0.7572
# Epoch 8/10
# 94/94 [==============================] - 34s 363ms/step - loss: 0.6241 - accuracy: 0.7791 - val_loss: 0.6229 - val_accuracy: 0.7787
# Epoch 9/10
# 94/94 [==============================] - 35s 368ms/step - loss: 0.6007 - accuracy: 0.7861 - val_loss: 0.6480 - val_accuracy: 0.7690
# Epoch 10/10
# 94/94 [==============================] - 33s 355ms/step - loss: 0.5792 - accuracy: 0.7944 - val_loss: 0.5892 - val_accuracy: 0.7922

# %% [markdown]
# Create a figure with two subplots. The first subplot should plot the training and validation loss (`loss` and `val_loss`) and the second subplot should plot the training and validation accuracy (`accuracy` and `val_accuracy`). Make sure you include the axis labels and a legend in each plot.

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))

# YOUR CODE HERE

ax1.plot(range(1, epochs+1), model_result.history['loss'], '-r', range(1, epochs+1), model_result.history['val_loss'], 'b--')
ax2.plot(range(1, epochs+1), model_result.history['accuracy'], '-r', range(1, epochs+1), model_result.history['val_accuracy'], 'b--')

ax1.legend(['Training Loss','Validation Loss'])
ax1.set_xlabel('No. of Epochs')
ax1.set_ylabel('Loss')

ax2.legend(['Training Accuracy','Validation Accuracy'])
ax2.set_xlabel('No. of Epochs')
ax2.set_ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Compute and print the test set accuracy. Note that your final accuracy may be different each time you run this due to the randomness in the validation split.

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

print("Test accuracy:", test_acc)
# Out:
# Test accuracy: 0.7915999889373779
